# %% [markdown]
# My version of a sandbox for testing.

# %%
import numpy as np
import matplotlib.pyplot as plt
from Utils.Power import PowerMethod, MultiPlotter

# %%
A = [
    [0.8, 0, 0.7, 0],
    [0, 0.9, 0.3, 0],
    [0.2, 0, 0, 0.0005],
    [0, 0.1, 0, 0.9995],]
A = np.array(A)


power = PowerMethod(A, 0.5)
powerB = PowerMethod(A, 0.8)
power.run(eigs=True)
powerB.run(eigs=True)
powers = [power, powerB]

# %%
mp = MultiPlotter(powers)
filters = None
label_attr = ['alpha']
mp.plot_residuals(filters, label_attr)
print(power.eigenvalues)
# Out:
# [-0.14771176  0.90030522  0.94690654  1.        ]
